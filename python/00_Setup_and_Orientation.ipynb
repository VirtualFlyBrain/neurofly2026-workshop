# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/00_Setup_and_Orientation.ipynb)

# %% [markdown]
# # 00 · Setup & the 2026 data landscape
# **VFB @ NeuroFly 2026 — Bridging connectomes and transcriptomics**
#
# By the end you'll have `vfb_connect` running, know the three routes we use throughout (**A** code · **B** MCP · **C** chat), and have seen the connectomes VFB integrates in 2026.
#
# This is an interactive notebook — add cells and experiment freely.

# %% [markdown]
# ## 1. Install & import

# %%
# Run once per Colab session (skip if already installed locally).
# vfb_connect pulls two legacy deps (jsonpath-rw, colormath) that only build on an
# older setuptools, so pin it first — otherwise the install fails on Colab:
# %pip install -q "setuptools<58" wheel
# %pip install -q vfb_connect navis navis-flybrains neuprint-python python-catmaid

# %%
# Modern entry point: a ready-made singleton that wraps VFB's public servers.
from vfb_connect import vfb
import pandas as pd

# (Legacy equivalent, as used in the 2024 notebooks:
#   from vfb_connect.cross_server_tools import VfbConnect; vc = VfbConnect() )

# %% [markdown]
# ## 2. The three routes
# Everything in this workshop can be done three ways. We'll show all three on each problem:
#
# | Route | What | Best for |
# |---|---|---|
# | **A · `vfb_connect`** | Python → DataFrames | reproducible analysis |
# | **B · VFB MCP** | [vfb3-mcp.virtualflybrain.org](https://vfb3-mcp.virtualflybrain.org) in an LLM | conversational, chainable |
# | **C · VFB chat** | [chat.virtualflybrain.org](https://chat.virtualflybrain.org) | zero-install lookups |
#
# Set up the no-code routes now: [`../no-code/`](../no-code/).

# %% [markdown]
# ## 3. What data is in VFB in 2026?
# The headline change since 2024 is whole-CNS and sex-specific connectomes. Let's list what's live right now rather than trusting a hard-coded list.

# %%
# All datasets VFB integrates (verified API method) — returns ~200 rows incl. LM & scRNAseq.
datasets = vfb.get_datasets()
print(len(datasets), 'datasets total')
datasets[['label', 'symbol', 'id']].head(20)
# Tip: the no-code MCP tool's list_connectome_datasets returns just the connectomes.

# %% [markdown]
# Expected in 2026 (verify live): **BANC** (whole CNS), **FlyWire/FAFB** v783, **male-CNS**, **Optic Lobe** v1.0.1, **MANC** v1.2.1, **Hemibrain** v1.2.1, **FAFB-CATMAID**, **L1 larval CNS**. The same list is available conversationally:

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "List the connectome datasets currently integrated in Virtual Fly Brain with their versions."

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "Which connectome datasets does VFB have, and which cover the ventral nerve cord?"

# %% [markdown]
# > **When to reach for which** — Use the API when a later cell needs the dataset list as data; use chat/MCP for a quick orientation or when teaching.

# %% [markdown]
# ### 🧪 Your turn
# Ask chat which datasets cover the **larval** CNS, then confirm with the API list above.
