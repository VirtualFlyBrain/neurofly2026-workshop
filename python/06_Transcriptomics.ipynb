# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/06_Transcriptomics.ipynb)

# %% [markdown]
# # 06 · Transcriptomics
# **Problem P6: What is this cell type's expression profile and marker genes?**

# %%
# Run once per Colab session (skip if already installed locally).
# vfb_connect pulls two legacy deps (jsonpath-rw, colormath) that only build on an
# older setuptools, so pin it first — otherwise the install fails on Colab:
# %pip install -q "setuptools<58" wheel
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly

# %%
# Modern entry point: a ready-made singleton that wraps VFB's public servers.
from vfb_connect import vfb
import pandas as pd

# (Legacy equivalent, as used in the 2024 notebooks:
#   from vfb_connect.cross_server_tools import VfbConnect; vc = VfbConnect() )

# %% [markdown]
# ## Route A — `vfb_connect`
# The connectomics↔transcriptomics bridge — the heart of the 2024 workshop, refreshed. VFB links cell types to scRNAseq clusters and expressed genes so you can go from a wiring diagram to gene expression and back.

# %%
# Expression / transcriptomics for a cell type (verified current API).
cell_type = 'Kenyon cell'  # <-- change me
profile = vfb.get_transcriptomic_profile(cell_type)
pd.DataFrame(profile).head()
# Also: vfb.get_cell_types_by_genes(genes=[...]) and
#       vfb.get_scRNAseq_expression(id) for the reverse direction.

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "What scRNAseq / expression data does VFB have for Kenyon cells, and which marker genes are associated with them?"

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "What genes are expressed in Kenyon cells?"

# %% [markdown]
# > **When to reach for which** — the API to *join* expression to connectivity for analysis; MCP/chat to survey what data exists.

# %% [markdown]
# ### 🧪 Your turn
# Pick a connectome cell type from an earlier module and find its expression profile. Which marker genes could label it?
