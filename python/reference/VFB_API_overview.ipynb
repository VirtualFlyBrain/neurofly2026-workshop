# %% [markdown]
# # Reference · VFB API overview
# A tour of the `vfb_connect` query surface.
#
# > Reference notebook carried over from the 2024 workshop — to refresh and validate against the current API/datasets (see `../../PLAN.md`).

# %%
# %pip install -q --upgrade vfb_connect navis neuprint-python python-catmaid

# %%
from vfb_connect import vfb
import pandas as pd
