# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/07_Putting_it_together.ipynb)

# %% [markdown]
# # 07 · Putting it together
# **Problem P7: a mini-project chaining every skill — twice.**

# %% [markdown]
# **First time in Colab?** Click the **▶ (play) icon** on the left edge of the code cell below to run it (or press `Shift+Enter`).
#
# You'll likely see a warning like:
#
# ```
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ```
#
# That's expected — Colab's own pre-installed packages briefly clash with one this notebook installs. It doesn't affect anything below; safe to ignore.

# %%
# Run once per Colab session (skip if already installed locally).
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly

# %%
from vfb_connect import vfb   # first import connects to VFB services (~2 min, then fast)
import pandas as pd

# %% [markdown]
# ## Route A — `vfb_connect`
# Do the full chain once with the API and once conversationally, then compare speed, confidence and reproducibility:
#
# 1. Pick a **region**. 2. Find its **intrinsic neuron types** (01). 3. Pick one and **visualise** it (03). 4. List its **strongest partners** (04). 5. Find its **cross-dataset match** (05). 6. Summarise its **expression** (06).

# %%
# Build your pipeline here, reusing calls from modules 01–06.
region = 'mushroom body'  # <-- change me
# ... your analysis ...

# %% [markdown]
# ---
# *This notebook is the Python route only. The MCP, chat, 3D-browser and R routes for this problem live on the [workshop page](https://workshop.virtualflybrain.org/sessions/session-7-putting-it-together/).*

# %% [markdown]
# ### 🧪 Your turn
# Swap in a region from your own research and run the whole chain. Which step was hardest, and why?
