# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/07_Putting_it_together.ipynb)

# %% [markdown]
# # 07 · Putting it together
# **Problem P7: a mini-project chaining every skill — twice.**

# %%
# Run once per Colab session (skip if already installed locally)
# %pip install -q --upgrade vfb_connect navis navis-flybrains neuprint-python python-catmaid

# %%
# Modern entry point: a ready-made singleton that wraps VFB's public servers.
from vfb_connect import vfb
import pandas as pd

# (Legacy equivalent, as used in the 2024 notebooks:
#   from vfb_connect.cross_server_tools import VfbConnect; vc = VfbConnect() )

# %% [markdown]
# ## Route A — `vfb_connect`
# Do the full chain once with the API and once conversationally, then compare speed, confidence and reproducibility:
#
# 1. Pick a **region**. 2. Find its **intrinsic neuron types** (01). 3. Pick one and **visualise** it (03). 4. List its **strongest partners** (04). 5. Find its **cross-dataset match** (05). 6. Summarise its **expression** (06).

# %%
# Build your pipeline here, reusing calls from modules 01–06.
region = 'mushroom body'  # <-- change me
# ... your analysis ...

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "Starting from the mushroom body: find its intrinsic neuron types, pick one, show it, list its main partners, find its closest match in another connectome, and summarise any expression data — give me all the VFB IDs so I can reproduce this in vfb_connect."

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "Walk me through the mushroom body: its main cell types, one example neuron, and what it connects to" — one question at a time.

# %% [markdown]
# > **When to reach for which** — explore fast with MCP/chat, capture the IDs, then reproduce the whole chain in `vfb_connect` for a figure or paper.

# %% [markdown]
# ### 🧪 Your turn
# Swap in a region from your own research and run the whole chain. Where did each route win?
