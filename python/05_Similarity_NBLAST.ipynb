# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/05_Similarity_NBLAST.ipynb)

# %% [markdown]
# # 05 · Similarity & NBLAST
# **Problem P5: What is the morphological match to this neuron in another dataset?**

# %%
# Run once per Colab session (skip if already installed locally)
# %pip install -q --upgrade vfb_connect navis navis-flybrains neuprint-python python-catmaid

# %%
# Modern entry point: a ready-made singleton that wraps VFB's public servers.
from vfb_connect import vfb
import pandas as pd

# (Legacy equivalent, as used in the 2024 notebooks:
#   from vfb_connect.cross_server_tools import VfbConnect; vc = VfbConnect() )

# %% [markdown]
# ## Route A — `vfb_connect`
# NBLAST ([Costa et al. 2016](https://doi.org/10.1016/j.neuron.2016.06.005)) scores morphological similarity. VFB precomputes cross-dataset NBLAST, so you can find the closest cell in another connectome — now including BANC, male-CNS and optic-lobe.

# %%
# Morphologically similar neurons to a query, across datasets (verified current API).
hits = vfb.get_similar_neurons('VFB_00101567', similarity_score='NBLAST_score')  # <-- your neuron ID
pd.DataFrame(hits).sort_values('NBLAST_score', ascending=False).head(10)
# Related: vfb.get_potential_drivers(neuron) finds GAL4/split lines by morphology.

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "Run an NBLAST similarity query for neuron VFB_00101567 and return the top cross-dataset matches with scores; note which come from BANC or male-CNS."

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "What neurons look most similar to VFB_00101567?"

# %% [markdown]
# > **When to reach for which** — the API when scores/thresholds matter for a claim; MCP/chat for a quick shortlist of candidates.

# %% [markdown]
# ### 🧪 Your turn
# Use NBLAST to propose a cross-dataset identity (feeds back into module 02). How confident are you, and why?
