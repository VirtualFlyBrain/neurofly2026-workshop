# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/03_Visualisation.ipynb)

# %% [markdown]
# # 03 · Visualisation
# **Problem P3: Show these neurons together in a common template.**

# %%
# Run once per Colab session (skip if already installed locally).
# vfb_connect pulls two legacy deps (jsonpath-rw, colormath) that only build on an
# older setuptools, so pin it first — otherwise the install fails on Colab:
# %pip install -q "setuptools<58" wheel
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly

# %%
# Run once per Colab session (skip if already installed locally).
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly

# %% [markdown]
# ## Route A — `vfb_connect`
# VFB returns neurons already in shared template space, so co-visualisation is direct. Load skeletons/meshes and plot with `navis`. For a no-code 3D view, VFB's website [Circuit Browser](https://virtualflybrain.org/docs/website-features/circuitbrowser/) and the MCP/chat image responses work in-browser.

# %%
import navis
# Download aligned skeletons (SWC) for a few IDs, then plot with navis.
ids = ['VFB_jrchjtdb', 'VFB_fw035286']  # two DA1 lPNs: hemibrain + FlyWire (from module 01)
vfb.get_images(ids, template='JRC2018Unisex', image_folder='./swc', image_type='swc')
neurons = navis.read_swc('./swc')
navis.plot3d(neurons)
# For a no-code 3D view, the same neurons open in the VFB website via vfb.get_vfb_link(ids, template=...).

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "Show me the 3D image of neuron VFB_jrchjtdb with two of its strongest partners in the same template."

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "Show me what neuron VFB_jrchjtdb looks like."

# %% [markdown]
# > **When to reach for which** — `navis` for publication figures and morphometrics; MCP/chat/Circuit Browser for a fast look or a demo.

# %% [markdown]
# ### 🧪 Your turn
# Co-visualise one neuron from two different connectomes. Do they occupy the same region?
