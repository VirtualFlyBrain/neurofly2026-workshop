# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VirtualFlyBrain/neurofly2026-workshop/blob/main/python/02_Bridging_datasets.ipynb)

# %% [markdown]
# # 02 · Bridging datasets & identity
# **Problem P2: Is this FlyWire neuron the same cell as that hemibrain one?**

# %%
# Run once per Colab session (skip if already installed locally).
# vfb_connect pulls two legacy deps (jsonpath-rw, colormath) that only build on an
# older setuptools, so pin it first — otherwise the install fails on Colab:
# %pip install -q "setuptools<58" wheel
# %pip install -q vfb_connect navis flybrains neuprint-python python-catmaid plotly

# %%
# Modern entry point: a ready-made singleton that wraps VFB's public servers.
from vfb_connect import vfb
import pandas as pd

# (Legacy equivalent, as used in the 2024 notebooks:
#   from vfb_connect.cross_server_tools import VfbConnect; vc = VfbConnect() )

# %% [markdown]
# ## Route A — `vfb_connect`
# Resolve two individuals, compare their ontology types, and confirm with morphology (NBLAST, module 05). Shared type + high NBLAST = strong cross-dataset identity. `vfb.terms()` fetches TermInfo; `vfb.get_vfb_link()` builds a website link to eyeball them side by side.

# %%
# Two real DA1 lPN individuals from different connectomes:
#   VFB_jrchjtdb  DA1_lPN_R, hemibrain (bodyId 1734350908)
#   VFB_fw035286  AL.MB_CA.83, FlyWire v783
# Fetch both in ONE call — vfb.terms() returns a VFBTerms collection, and .summary
# gives a tidy DataFrame. (Calling terms() per-id and concatenating works but is
# slower and emits a "VFBTerm only has one item" warning for every field.)
pair = vfb.terms(['VFB_jrchjtdb', 'VFB_fw035286'])

# Inspect the parent (type) labels to see whether they share a classification.
pair.summary[['ID', 'Name', 'Parents', 'Datasets']]

# %% [markdown]
# #### Route B — VFB MCP tool (in your LLM)
#
# Set up once via [`../no-code/MCP_setup.md`](../no-code/MCP_setup.md), then ask:
#
# > "Find the FlyWire match for hemibrain neuron VFB_jrchjtdb and tell me if they share a cell type."

# %% [markdown]
# #### Route C — chat.virtualflybrain.org
#
# No setup — open [chat.virtualflybrain.org](https://chat.virtualflybrain.org) and ask:
#
# > "Is there a FlyWire equivalent of this hemibrain DA1 lPN neuron?"

# %% [markdown]
# > **When to reach for which** — the API for a defensible, reproducible mapping you can cite; MCP/chat to explore candidates first.

# %% [markdown]
# ### 🧪 Your turn
# Take a neuron from a **new** 2026 dataset (BANC or male-CNS) and find its counterpart in an older connectome. Do the types agree?
